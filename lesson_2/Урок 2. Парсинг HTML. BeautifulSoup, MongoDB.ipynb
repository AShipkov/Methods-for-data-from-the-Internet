# %% [markdown]
# Необходимо собрать информацию о вакансиях на вводимую должность (используем input или через аргументы) с сайта superjob.ru и hh.ru. Приложение должно анализировать несколько страниц сайта(также вводим через input или аргументы). Получившийся список должен содержать в себе минимум:
# *Наименование вакансии
# *Предлагаемую зарплату (отдельно мин. и отдельно макс. и отдельно валюта)
# *Ссылку на саму вакансию
# *Сайт откуда собрана вакансия

# %% [markdown]
# По своему желанию можно добавить еще работодателя и расположение. Данная структура должна быть одинаковая для вакансий с обоих сайтов. Общий результат можно вывести с помощью dataFrame через pandas.

# %%
from bs4 import BeautifulSoup as bs
import requests
import re
import pandas as pd
import json

# %%
class hh():
    def __init__(self,s_key):
        self.mian_link ='https://lipetsk.hh.ru'
        self.s_key=s_key

    def get_vacancies(self):
        url = '/search/vacancy'
        params = {'area': '2', 'clusters=true': 'true', 'enable_snippets': 'true', 'text': self.s_key,
                  'only_with_salary': 'true', 'salary': '185000', 'from': 'cluster_compensation',
                  'showClusters': 'true'}
        header = {
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.138 Safari/537.36',
            'Accept': '*/*'}
        response = requests.get(self.mian_link + url, headers=header, params=params)
        soup = bs(response.text, 'lxml')
        my_data = soup.find_all('div', {'class': "vacancy-serp-item"})
        my_list = []
        self.__get_info_from_page(my_data,my_list)
        page = soup.find('script', {'data-name': 'HH/Pager'})
        num_pages=json.loads(page['data-params'])['pagesCount']
        while num_pages > 1:
            params = {'area': '2', 'clusters=true': 'true', 'enable_snippets': 'true', 'text': self.s_key,
                      'only_with_salary': 'true', 'salary': '185000', 'from': 'cluster_compensation',
                      'showClusters': 'true','page':str((num_pages-1))}
            response = requests.get(self.mian_link + url, headers=header, params=params)
            soup = bs(response.text, 'lxml')
            my_data = soup.find_all('div', {'class': "vacancy-serp-item"})
            self.__get_info_from_page(my_data, my_list)
            num_pages-=1
        return my_list

    def __get_info_from_page(self,my_data,my_list):
        for i in my_data:
            my_dict = {}
            my_dict['Позиция'] = i.find('a', {'class': 'HH-LinkModifier'}).getText()
            my_dict['Link'] = i.find('a', {'class': 'HH-LinkModifier'})['href']
            if i.find('a', {'data-qa': 'vacancy-serp__vacancy-employer'}):
                my_dict['Организация'] = i.find('a', {'data-qa': 'vacancy-serp__vacancy-employer'}).text
            else:
                my_dict['Организация'] = "No Data"
            if i.find('span', {'data-qa': 'vacancy-serp__vacancy-compensation'}):
                salary = self.__get_salary(i.find('span', {'data-qa': 'vacancy-serp__vacancy-compensation'}).text)
            my_dict['Зарплата мин'] = salary['min']
            my_dict['Зарплата макс'] = salary['max']
            my_dict['Валюта'] = salary['currency']
            my_dict['Ресурс'] = self.mian_link
            my_list.append(my_dict)

    def __get_salary(self,str):
          salary = {}
          if str[:2] == 'от':
              min = re.search(r'[\d\s]+', str)[0]
              min = int(re.sub(r"\s", '', min))
              max = None
          elif str[:2] == 'до':
              max = re.search(r'[\d\s]+', str)[0]
              max = int(re.sub(r"\s", '', max))
              min = None
          else:
              min = re.search(r'[\d\s]+', str)[0]
              min = int(re.sub(r"\s", '', min))
              max = re.search(r'-([\d\s]+)', str)[1]
              max = int(re.sub(r"\s", '', max))
          currency = re.search(r'[A-Zа-я]{3}', str)[0]
          salary['min'] = min
          salary['max'] = max
          salary['currency'] = currency
          return salary

# %%
class sj():
    def __init__(self,s_key):
        self.mian_link ='https://spb.superjob.ru'
        self.s_key=s_key

    def get_vacancies_from_with_salary(self):
        url = '/vacancy/search'
        params = { 'keywords': self.s_key, 'payment_defined':'1'}
        header = {
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.138 Safari/537.36',
            'Accept': '*/*'}
        response = requests.get(self.mian_link + url, headers=header, params=params)
        soup = bs(response.text, 'lxml')
        my_data = soup.find_all('div', {'class': "iJCa5 f-test-vacancy-item _1fma_ _1JhPh _2gFpt _1znz6 _2nteL"})
        my_list = []
        self.__get_info_from_page(my_data, my_list)
        while soup.find('a', {'rel': 'next'}):
            page=soup.find('a', {'rel': 'next'})['href']
            params = { 'keywords': self.s_key, 'payment_defined':'1'}
            response = requests.get(self.mian_link +page, headers=header, params=params)
            soup = bs(response.text, 'lxml')
            my_data = soup.find_all('div', {'class': "iJCa5 f-test-vacancy-item _1fma_ _1JhPh _2gFpt _1znz6 _2nteL"})
            self.__get_info_from_page(my_data, my_list)
        return my_list

    def __get_info_from_page(self, my_data, my_list):
        for i in my_data:
            my_dict = {}
            my_dict['Позиция'] = i.find('a').getText()
            my_dict['Link'] = self.mian_link+i.find('a')['href']
            my_dict['Организация'] = i.find('a', {'class':'_25-u7'}).text
            sal=i.find('span', {'class': 'PlM3e'}).text
            salary = self.__get_salary(sal)
            my_dict['Зарплата мин'] = salary['min']
            my_dict['Зарплата макс'] = salary['max']
            my_dict['Валюта'] = salary['currency']
            my_dict['Ресурс'] = self.mian_link
            my_list.append(my_dict)
        # print(my_dict)

    def __get_salary(self, str):
        salary = {}
        if str[:2] == 'от':
            min = re.search(r'[\d\s]+', str)[0]
            min = int(re.sub(r"\s", '', min))
            max = None
            currency = re.search(r'[A-Zа-я]{3}', str)[0]
        elif str[:2] == 'до':
            max = re.search(r'[\d\s]+', str)[0]
            max = int(re.sub(r"\s", '', max))
            min = None
            currency = re.search(r'[A-Zа-я]{3}', str)[0]
        elif '-' in str:
            min = re.search(r'[\d\s]+', str)[0]
            min = int(re.sub(r"\s", '', min))
            max = re.search(r'-([\d\s]+)', str)[1]
            max = int(re.sub(r"\s", '', max))
            currency = re.search(r'[A-Zа-я]{3}', str)[0]
        elif str=="По договорённости":
            min=None
            max=None
            currency = None
        else:
            min = re.search(r'[\d\s]+', str)[0]
            min = int(re.sub(r"\s", '', min))
            max = re.search(r'[\d\s]+', str)[0]
            max = int(re.sub(r"\s", '', max))
            currency = re.search(r'[A-Zа-я]{3}', str)[0]
        salary['min'] = min
        salary['max'] = max
        salary['currency'] = currency
        return salary

# %%
vac_hh=hh('Pithon')
vac_sj = sj('Pithon')

# %%
df = pd.DataFrame(vac_hh.get_vacancies()+vac_sj.get_vacancies_from_with_salary())

# %%
df[60:]
# Out:
#                                               Позиция  \
# 60                        Программист-разработчик C++
# 61                             C++ developer (Berlin)
# 62                     Lead Python Developer (Cyprus)
# 63            DevOps Engineer for an AI Swiss Startup
# 64  DevOps / Infrastructure Engineer / Инженер по ...
# 65                 Senior backend developer/Team Lead
# 66                 Python Developer with AWS (remote)
# 67     Senior Software Developer (Kotlin IDE/Tooling)
# 68          Senior Software Developer (IntelliJ IDEA)
# 69                Senior Software Developer (PyCharm)
# 70       Software Engineer (IntelliJ IDEA: Profilers)
# 71                      Software Developer (PhpStorm)
# 72                                   Reverse engineer
# 73      Software Developer (PyCharm For Data Science)
# 74                           UI/UX Designer (PyCharm)
# 75          Software Developer (Marketing Automation)
# 76              Java Developer (Educational Products)
# 77                        QA Engineer (IntelliJ IDEA)
# 78   Java Swing Developer (IntelliJ Platform UI Team)
# 79                    Software Engineer (JVM Runtime)
# 80                 Software Developer (Space Hosting)
# 81         Senior Software Developer (Space Packages)
# 82                     Infrastructure/DevOps engineer
# 83  DevOps Engineer (Business Applications Develop...
# 84                                      Senior DevOps
# 85                                Data engineer (AWS)
# 86  Big Data Administrator / System Administrator ...
# 87                         Deep Learning/ CV Engineer
# 88                  Python, Java разработчик (Лондон)
# 89  Senior Software Engineer (Python/Devops) for a...
# 90                              Архитектор Blockchain
# 91                       Lead Ruby on Rails Developer
# 92               Lead QA Engineer for a Swiss Startup
# 93                            Программист 1 категории
# 94  Инженер по качеству (для людей с ограниченными...
# 95  Ассистент/доцент кафедры информатики и компьют...
# 96         Инженер встроенных систем / Linux Embedded
# 97                            Системный администратор
# 98            Системный администратор / IT-специалист
#
#                                                  Link  \
# 60  https://lipetsk.hh.ru/vacancy/37784178?query=P...
# 61  https://lipetsk.hh.ru/vacancy/36275846?query=P...
# 62  https://lipetsk.hh.ru/vacancy/37755576?query=P...
# 63  https://lipetsk.hh.ru/vacancy/37769840?query=P...
# 64  https://lipetsk.hh.ru/vacancy/37758901?query=P...
# 65  https://lipetsk.hh.ru/vacancy/37753418?query=P...
# 66  https://lipetsk.hh.ru/vacancy/37735051?query=P...
# 67  https://lipetsk.hh.ru/vacancy/24246955?query=P...
# 68  https://lipetsk.hh.ru/vacancy/18562648?query=P...
# 69  https://lipetsk.hh.ru/vacancy/22056926?query=P...
# 70  https://lipetsk.hh.ru/vacancy/26949603?query=P...
# 71  https://lipetsk.hh.ru/vacancy/27193466?query=P...
# 72  https://lipetsk.hh.ru/vacancy/37497245?query=P...
# 73  https://lipetsk.hh.ru/vacancy/35336500?query=P...
# 74  https://lipetsk.hh.ru/vacancy/36026441?query=P...
# 75  https://lipetsk.hh.ru/vacancy/36863995?query=P...
# 76  https://lipetsk.hh.ru/vacancy/36863909?query=P...
# 77  https://lipetsk.hh.ru/vacancy/33488505?query=P...
# 78  https://lipetsk.hh.ru/vacancy/26133511?query=P...
# 79  https://lipetsk.hh.ru/vacancy/31364469?query=P...
# 80  https://lipetsk.hh.ru/vacancy/36863266?query=P...
# 81  https://lipetsk.hh.ru/vacancy/36863784?query=P...
# 82  https://lipetsk.hh.ru/vacancy/36863901?query=P...
# 83  https://lipetsk.hh.ru/vacancy/36863771?query=P...
# 84  https://lipetsk.hh.ru/vacancy/37692456?query=P...
# 85  https://lipetsk.hh.ru/vacancy/37710264?query=P...
# 86  https://lipetsk.hh.ru/vacancy/36693866?query=P...
# 87  https://lipetsk.hh.ru/vacancy/37655433?query=P...
# 88  https://lipetsk.hh.ru/vacancy/37167329?query=P...
# 89  https://lipetsk.hh.ru/vacancy/37675980?query=P...
# 90  https://lipetsk.hh.ru/vacancy/37147510?query=P...
# 91  https://lipetsk.hh.ru/vacancy/37615319?query=P...
# 92  https://lipetsk.hh.ru/vacancy/37633092?query=P...
# 93  https://spb.superjob.ru/vakansii/programmist-1...
# 94  https://spb.superjob.ru/vakansii/inzhener-po-k...
# 95  https://spb.superjob.ru/vakansii/assistent-113...
# 96  https://spb.superjob.ru/vakansii/inzhener-vstr...
# 97  https://spb.superjob.ru/vakansii/sistemnyj-adm...
# 98  https://spb.superjob.ru/vakansii/sistemnyj-adm...
#
#                                           Организация  Зарплата мин  \
# 60                                      ООО Софтвелум      180000.0
# 61                                        Cellar door           NaN
# 62                                               IBIT        3000.0
# 63                            Assaia International AG        2500.0
# 64                                            HitHunt      150000.0
# 65                                           O.Vision      200000.0
# 66                                 Nitka Technologies        3000.0
# 67                                          JetBrains      200000.0
# 68                                          JetBrains      200000.0
# 69                                          JetBrains      180000.0
# 70                                          JetBrains      200000.0
# 71                                          JetBrains      200000.0
# 72                                     HR Development       60000.0
# 73                                          JetBrains      200000.0
# 74                                          JetBrains      150000.0
# 75                                          JetBrains      180000.0
# 76                                          JetBrains      180000.0
# 77                                          JetBrains      150000.0
# 78                                          JetBrains      200000.0
# 79                                          JetBrains      200000.0
# 80                                          JetBrains      200000.0
# 81                                          JetBrains      200000.0
# 82                                          JetBrains      200000.0
# 83                                          JetBrains      180000.0
# 84                                   ООО Маркет Плато      160000.0
# 85                                     ООО ClearScale        4000.0
# 86                                           QuadCode      140000.0
# 87                                           ООО АРЕС      180000.0
# 88                                     Бачинская Юлия      200000.0
# 89                            Assaia International AG        2500.0
# 90   Отраслевой центр разработки и внедрения инфор...      190000.0
# 91                      Software Consulting Solutions           NaN
# 92                            Assaia International AG        2500.0
# 93                             "Концерн "НПО "Аврора"           NaN
# 94                               Кадровое решение СПб       70000.0
# 95  Горный университет, Кафедра информатики и комп...       80000.0
# 96                                Группа компаний MVS      150000.0
# 97                                             ГАРАНТ           NaN
# 98                          Городская поликлиника №34       45000.0
#
#     Зарплата макс Валюта                   Ресурс
# 60            NaN    руб    https://lipetsk.hh.ru
# 61        10000.0    EUR    https://lipetsk.hh.ru
# 62            NaN    EUR    https://lipetsk.hh.ru
# 63         3500.0    USD    https://lipetsk.hh.ru
# 64            NaN    руб    https://lipetsk.hh.ru
# 65       350000.0    руб    https://lipetsk.hh.ru
# 66         3200.0    USD    https://lipetsk.hh.ru
# 67            NaN    руб    https://lipetsk.hh.ru
# 68            NaN    руб    https://lipetsk.hh.ru
# 69            NaN    руб    https://lipetsk.hh.ru
# 70            NaN    руб    https://lipetsk.hh.ru
# 71            NaN    руб    https://lipetsk.hh.ru
# 72       200000.0    руб    https://lipetsk.hh.ru
# 73            NaN    руб    https://lipetsk.hh.ru
# 74            NaN    руб    https://lipetsk.hh.ru
# 75            NaN    руб    https://lipetsk.hh.ru
# 76            NaN    руб    https://lipetsk.hh.ru
# 77            NaN    руб    https://lipetsk.hh.ru
# 78            NaN    руб    https://lipetsk.hh.ru
# 79            NaN    руб    https://lipetsk.hh.ru
# 80            NaN    руб    https://lipetsk.hh.ru
# 81            NaN    руб    https://lipetsk.hh.ru
# 82            NaN    руб    https://lipetsk.hh.ru
# 83            NaN    руб    https://lipetsk.hh.ru
# 84       200000.0    руб    https://lipetsk.hh.ru
# 85            NaN    USD    https://lipetsk.hh.ru
# 86       230000.0    руб    https://lipetsk.hh.ru
# 87       300000.0    руб    https://lipetsk.hh.ru
# 88            NaN    руб    https://lipetsk.hh.ru
# 89         3500.0    USD    https://lipetsk.hh.ru
# 90       190000.0    руб    https://lipetsk.hh.ru
# 91         3500.0    USD    https://lipetsk.hh.ru
# 92         3500.0    USD    https://lipetsk.hh.ru
# 93       120000.0    руб  https://spb.superjob.ru
# 94            NaN    руб  https://spb.superjob.ru
# 95        80000.0    руб  https://spb.superjob.ru
# 96            NaN    руб  https://spb.superjob.ru
# 97        35000.0    руб  https://spb.superjob.ru
# 98            NaN    руб  https://spb.superjob.ru
