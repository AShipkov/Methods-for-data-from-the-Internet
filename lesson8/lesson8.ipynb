# %%
from pymongo import MongoClient
import pandas as pd

# %%
client = MongoClient('mongodb://localhost:27017/')
db = client.instagram

# %%
df = pd.DataFrame(client.instagram.subscriptions.find())
df
# Out:
#                        _id     user_id  subscriber_status           id  \
# 0     96709902022043003929  9670990202                  1   2043003929
# 1     77090578106033212949  7709057810                  1   6033212949
# 2     96709902022259847077  9670990202                  1   2259847077
# 3    770905781017888808812  7709057810                  1  17888808812
# 4     96709902021107450891  9670990202                  1   1107450891
# ..                     ...         ...                ...          ...
# 460   77090578108547792177  7709057810                  1   8547792177
# 461  770905781038576815175  7709057810                  1  38576815175
# 462   77090578107506492115  7709057810                  1   7506492115
# 463    7709057810491775876  7709057810                  1    491775876
# 464   77090578105721291090  7709057810                  1   5721291090
#
#                            name  \
# 0              khaalid_abdi_ali
# 1                mahmoud.alaa.9
# ...

# %%
df[df['name'].isin(['hse_aneek', 'mom_call_me_moses'])]
# Out:
#                       _id     user_id  subscriber_status          id  \
# 2    96709902022259847077  9670990202                  1  2259847077
# 198    967099020247806230  9670990202                  1    47806230
#
#                   name                                              photo  \
# 2            hse_aneek  https://scontent-hel2-1.cdninstagram.com/v/t51...
# 198  mom_call_me_moses  https://scontent-hel2-1.cdninstagram.com/v/t51...
#
#                                              full_info
# 2    {'id': '2259847077', 'username': 'hse_aneek', ...
# 198  {'id': '47806230', 'username': 'mom_call_me_mo...

# %%
df[df['user_id'].isin(['7709057810'])]
# Out:
#                        _id     user_id  subscriber_status           id  \
# 1     77090578106033212949  7709057810                  1   6033212949
# 3    770905781017888808812  7709057810                  1  17888808812
# 5     77090578102059625070  7709057810                  1   2059625070
# 7    770905781031229497539  7709057810                  1  31229497539
# 9     77090578103621159948  7709057810                  1   3621159948
# ..                     ...         ...                ...          ...
# 460   77090578108547792177  7709057810                  1   8547792177
# 461  770905781038576815175  7709057810                  1  38576815175
# 462   77090578107506492115  7709057810                  1   7506492115
# 463    7709057810491775876  7709057810                  1    491775876
# 464   77090578105721291090  7709057810                  1   5721291090
#
#                      name                                              photo  \
# ...

# %%
df[df['user_id'].isin(['9670990202'])]
# Out:
#                        _id     user_id  subscriber_status           id  \
# 0     96709902022043003929  9670990202                  1   2043003929
# 2     96709902022259847077  9670990202                  1   2259847077
# 4     96709902021107450891  9670990202                  1   1107450891
# 6     96709902026085070896  9670990202                  1   6085070896
# 8     96709902028082395419  9670990202                  1   8082395419
# ..                     ...         ...                ...          ...
# 416   96709902021795853325  9670990202                  1   1795853325
# 417  967099020234217961410  9670990202                  1  34217961410
# 418   96709902027079172215  9670990202                  1   7079172215
# 419  967099020225362161071  9670990202                  1  25362161071
# 420   96709902026100216813  9670990202                  1   6100216813
#
#                            name  \
# 0              khaalid_abdi_ali
# 2                     hse_aneek
# ...
