# %%
from pymongo import MongoClient
import pandas as pd

# %%
client = MongoClient('mongodb://localhost:27017/')
db = client.vacancy.hhru

# %%
df = pd.DataFrame(client.vacancy.hhru.find())
df[['name','salary','employer','link','source']]
# Out:
#                                               name  \
# 0           Программист-разработчик python (midle)
# 1                     Backend разработчик (Python)
# 2     Python-программист (backend, infrastructure)
# 3                               Программист Python
# 4                Python-разработчик системы защиты
# ...                                            ...
# 1995                            Разработчик Python
# 1996                     Software Engineer (C/C++)
# 1997               Computer Vision Developer (C++)
# 1998                       Senior Python Developer
# 1999                     Программист Python/Golang
#
#                                                  salary          employer  \
# 0      [от , 100 000,  до , 180 000,  , руб.,  на руки]      CATAPULTO.RU
# 1                     [от , 100 000,  , руб.,  на руки]           LiteBox
# 2      [от , 140 000,  до , 200 000,  , руб.,  на руки]           МФТИ ГУ
# ...

# %%
df = pd.DataFrame(client.vacancy.superjobru.find())
df[['name','salary','employer','link','source']]
# Out:
#                                                   name  \
# 0                          Python-разработчик (Django)
# 1                                 Frontend-разработчик
# 2                                 Разработчик NetSuite
# 3                        Chief Technical Officer (CTO)
# 4                       Системный администратор DevOps
# ..                                                 ...
# 102                               Продуктовый аналитик
# 103                                      Биоинформатик
# 104  Педагог дополнительного образования (робототех...
# 105                                Учитель информатики
# 106                                   DevOps Architect
#
#                                              salary  \
# 0    [150 000,  , —,  , 200 000,  , руб., /, месяц]
# 1                               [По договорённости]
# 2                               [По договорённости]
# 3                               [По договорённости]
# ...

# %%
df = pd.DataFrame(client.books.book24.find())
df[['name','autor','discount_price','price','rating','link','source']]
# Out:
#                                                  name               autor  \
# 0                  Изучаем программирование на Python           Бэрри Пол
# 1                             Программируем на Python            Доусон М
# 2          Программирование для детей на языке Python     Банкрашков А.В.
# 3   Изучаем Python. Программирование игр, визуализ...             Мэтиз Э
# 4   Программируем с Minecraft. Создай свой мир с п...                None
# 5   Основы Data Science и Big Data. Python и наука...          Силен Дэви
# 6   Классические задачи Computer Science на языке ...                None
# 7   Python для детей. Самоучитель по программированию      Джейсон Бриггс
# 8   Python: Искусственный интеллект, большие данны...           Дейтел П.
# 9   Простой Python. Современный стиль программиров...                None
# 10    Программирование на Python в примерах и задачах    Васильев Алексей
# 11  Изучаем Python: программирование игр, визуализ...             Мэтиз Э
# ...

# %%
df = pd.DataFrame(client.books.labirint.find())
df[['name','autor','discount_price','price','rating','link','source']]
# Out:
#                                                   name  \
# 0    "Основы программирования на языке Python" Дмит...
# 1    "Изучаем Python. Программирование игр, визуали...
# 2    "Python. Разработка на основе тестирования" Га...
# 3    "Классические задачи Computer Science на языке...
# 4    "Алгоритмы обучения с подкреплением на Python"...
# ..                                                 ...
# 98   "Программирование на Python. Иллюстрированное ...
# 99         "Python для детей и родителей" Брайсон Пэйн
# 100             "Программируем на Python" Майкл Доусон
# 101  "Python для детей. Самоучитель по программиров...
# 102  "Python для детей. Самоучитель по программиров...
#
#                                 autor discount_price price rating  \
# 0    Златопольский Дмитрий Михайлович            595   827   8.64
# 1                          Мэтиз Эрик            997  1385   9.00
# 2                     Персиваль Гарри           2202  3059   7.75
# ...
